# %%
#%matplotlib inline
# %matplotlib notebook

import matplotlib as mp

import numpy as np

import scipy as sp

import scipy.linalg as spl

import scipy.signal as sps

import glob

import json

import urllib3

from datetime import datetime 

import dateutil.parser as dp

import matplotlib.pyplot as pl

import re

import obspy

from obspy.core import UTCDateTime

import geomagio

from geomagio.edge import EdgeFactory
from geomagio.iaga2002 import IAGA2002Factory

#from geomagio.Algorithm import DeltaFAlgorithm

# %%
urlTemplate = 'file://' + '/Users/aclaycomb/Downloads/' + '{obs}{date:%Y%m%d}p.{i}'
urlInterval = 86400
a = IAGA2002Factory(urlTemplate = urlTemplate,
      urlInterval = urlInterval)

# %%
# !cd /Users/aclaycomb/Downloads/

# %%
b = a.get_timeseries(channels=['D','H','Z','F'], observatory="jco", starttime=UTCDateTime("2018-09-24T00:00Z"), endtime=UTCDateTime("2018-09-28T12:00Z"),type="variation",interval="minute")

# %%
b.plot()
pl.show()
pl.savefig("test.png")
# Out:
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="640">

# %%
b[0].data
# Out:
# array([0.30065914, 0.30023736, 0.30034789, ..., 0.30166562, 0.30177034,
#        0.30179652])

# %%
startt = 1441 + 1000
endt = 2880
pl.plot(b[3].data[startt:endt])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
pl.plot(b[1])
